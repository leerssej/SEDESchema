# %%
import pandas as pd
import numpy as np

isc = pd.read_csv("information_schema.columns.csv")
isc
# for SQL prepared
# https://data.stackexchange.com/stackoverflow/query/edit/1000399
# isc = pd.read_csv("SEDE_tabsColsTypes.csv")
# Out:
#      TABLE_CATALOG TABLE_SCHEMA        TABLE_NAME            COLUMN_NAME  \
# 0    StackOverflow          dbo             Users                     Id
# 1    StackOverflow          dbo             Users             Reputation
# 2    StackOverflow          dbo             Users           CreationDate
# 3    StackOverflow          dbo             Users            DisplayName
# 4    StackOverflow          dbo             Users         LastAccessDate
# 5    StackOverflow          dbo             Users             WebsiteUrl
# 6    StackOverflow          dbo             Users               Location
# 7    StackOverflow          dbo             Users                AboutMe
# 8    StackOverflow          dbo             Users                  Views
# 9    StackOverflow          dbo             Users                UpVotes
# 10   StackOverflow          dbo             Users              DownVotes
# 11   StackOverflow          dbo             Users        ProfileImageUrl
# 12   StackOverflow          dbo             Users              EmailHash
# 13   StackOverflow          dbo             Users              AccountId
# 14   StackOverflow          dbo         PostTypes                     Id
# 15   StackOverflow          dbo         PostTypes                   Name
# 16   StackOverflow          dbo  PostsWithDeleted                     Id
# 17   StackOverflow          dbo  PostsWithDeleted             PostTypeId
# 18   StackOverflow          dbo  PostsWithDeleted       AcceptedAnswerId
# 19   StackOverflow          dbo  PostsWithDeleted               ParentId
# 20   StackOverflow          dbo  PostsWithDeleted           CreationDate
# 21   StackOverflow          dbo  PostsWithDeleted           DeletionDate
# 22   StackOverflow          dbo  PostsWithDeleted                  Score
# 23   StackOverflow          dbo  PostsWithDeleted              ViewCount
# 24   StackOverflow          dbo  PostsWithDeleted                   Body
# 25   StackOverflow          dbo  PostsWithDeleted            OwnerUserId
# 26   StackOverflow          dbo  PostsWithDeleted       OwnerDisplayName
# 27   StackOverflow          dbo  PostsWithDeleted       LastEditorUserId
# 28   StackOverflow          dbo  PostsWithDeleted  LastEditorDisplayName
# 29   StackOverflow          dbo  PostsWithDeleted           LastEditDate
# ..             ...          ...               ...                    ...
# 173  StackOverflow          dbo       PostNotices         DeletionUserId
# 174  StackOverflow          dbo              Tags                     Id
# 175  StackOverflow          dbo              Tags                TagName
# 176  StackOverflow          dbo              Tags                  Count
# 177  StackOverflow          dbo              Tags          ExcerptPostId
# 178  StackOverflow          dbo              Tags             WikiPostId
# 179  StackOverflow          dbo          PostTags                 PostId
# 180  StackOverflow          dbo          PostTags                  TagId
# 181  StackOverflow          dbo             Posts                     Id
# 182  StackOverflow          dbo             Posts             PostTypeId
# 183  StackOverflow          dbo             Posts       AcceptedAnswerId
# 184  StackOverflow          dbo             Posts               ParentId
# 185  StackOverflow          dbo             Posts           CreationDate
# 186  StackOverflow          dbo             Posts           DeletionDate
# 187  StackOverflow          dbo             Posts                  Score
# 188  StackOverflow          dbo             Posts              ViewCount
# 189  StackOverflow          dbo             Posts                   Body
# 190  StackOverflow          dbo             Posts            OwnerUserId
# 191  StackOverflow          dbo             Posts       OwnerDisplayName
# 192  StackOverflow          dbo             Posts       LastEditorUserId
# 193  StackOverflow          dbo             Posts  LastEditorDisplayName
# 194  StackOverflow          dbo             Posts           LastEditDate
# 195  StackOverflow          dbo             Posts       LastActivityDate
# 196  StackOverflow          dbo             Posts                  Title
# 197  StackOverflow          dbo             Posts                   Tags
# 198  StackOverflow          dbo             Posts            AnswerCount
# 199  StackOverflow          dbo             Posts           CommentCount
# 200  StackOverflow          dbo             Posts          FavoriteCount
# 201  StackOverflow          dbo             Posts             ClosedDate
# 202  StackOverflow          dbo             Posts     CommunityOwnedDate
#
#      ORDINAL_POSITION  COLUMN_DEFAULT IS_NULLABLE DATA_TYPE  \
# 0                   1             NaN          NO       int
# 1                   2             NaN          NO       int
# 2                   3             NaN          NO  datetime
# 3                   4             NaN         YES  nvarchar
# 4                   5             NaN          NO  datetime
# 5                   6             NaN         YES  nvarchar
# 6                   7             NaN         YES  nvarchar
# 7                   8             NaN         YES  nvarchar
# 8                   9             NaN          NO       int
# 9                  10             NaN          NO       int
# 10                 11             NaN          NO       int
# 11                 12             NaN         YES  nvarchar
# 12                 13             NaN         YES   varchar
# 13                 14             NaN         YES       int
# 14                  1             NaN          NO   tinyint
# 15                  2             NaN          NO  nvarchar
# 16                  1             NaN          NO       int
# 17                  2             NaN          NO   tinyint
# 18                  3             NaN         YES       int
# 19                  4             NaN         YES       int
# 20                  5             NaN          NO  datetime
# 21                  6             NaN         YES  datetime
# 22                  7             NaN          NO       int
# 23                  8             NaN         YES       int
# 24                  9             NaN         YES  nvarchar
# 25                 10             NaN         YES       int
# 26                 11             NaN         YES  nvarchar
# 27                 12             NaN         YES       int
# 28                 13             NaN         YES  nvarchar
# 29                 14             NaN         YES  datetime
# ..                ...             ...         ...       ...
# 173                 9             NaN         YES       int
# 174                 1             NaN          NO       int
# 175                 2             NaN         YES  nvarchar
# 176                 3             NaN          NO       int
# 177                 4             NaN         YES       int
# 178                 5             NaN         YES       int
# 179                 1             NaN          NO       int
# 180                 2             NaN          NO       int
# 181                 1             NaN          NO       int
# 182                 2             NaN          NO   tinyint
# 183                 3             NaN         YES       int
# 184                 4             NaN         YES       int
# 185                 5             NaN          NO  datetime
# 186                 6             NaN         YES  datetime
# 187                 7             NaN          NO       int
# 188                 8             NaN         YES       int
# 189                 9             NaN         YES  nvarchar
# 190                10             NaN         YES       int
# 191                11             NaN         YES  nvarchar
# 192                12             NaN         YES       int
# 193                13             NaN         YES  nvarchar
# 194                14             NaN         YES  datetime
# 195                15             NaN         YES  datetime
# 196                16             NaN         YES  nvarchar
# 197                17             NaN         YES  nvarchar
# 198                18             NaN         YES       int
# 199                19             NaN         YES       int
# 200                20             NaN         YES       int
# 201                21             NaN         YES  datetime
# 202                22             NaN         YES  datetime
#
#      CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH     ...      \
# 0                         NaN                     NaN     ...
# 1                         NaN                     NaN     ...
# 2                         NaN                     NaN     ...
# 3                        40.0                    80.0     ...
# 4                         NaN                     NaN     ...
# 5                       200.0                   400.0     ...
# 6                       100.0                   200.0     ...
# 7                        -1.0                    -1.0     ...
# 8                         NaN                     NaN     ...
# 9                         NaN                     NaN     ...
# 10                        NaN                     NaN     ...
# 11                      200.0                   400.0     ...
# 12                       32.0                    32.0     ...
# 13                        NaN                     NaN     ...
# 14                        NaN                     NaN     ...
# 15                       50.0                   100.0     ...
# 16                        NaN                     NaN     ...
# 17                        NaN                     NaN     ...
# 18                        NaN                     NaN     ...
# 19                        NaN                     NaN     ...
# 20                        NaN                     NaN     ...
# 21                        NaN                     NaN     ...
# 22                        NaN                     NaN     ...
# 23                        NaN                     NaN     ...
# 24                       -1.0                    -1.0     ...
# 25                        NaN                     NaN     ...
# 26                       40.0                    80.0     ...
# 27                        NaN                     NaN     ...
# 28                       40.0                    80.0     ...
# 29                        NaN                     NaN     ...
# ..                        ...                     ...     ...
# 173                       NaN                     NaN     ...
# 174                       NaN                     NaN     ...
# 175                      35.0                    70.0     ...
# 176                       NaN                     NaN     ...
# 177                       NaN                     NaN     ...
# 178                       NaN                     NaN     ...
# 179                       NaN                     NaN     ...
# 180                       NaN                     NaN     ...
# 181                       NaN                     NaN     ...
# 182                       NaN                     NaN     ...
# 183                       NaN                     NaN     ...
# 184                       NaN                     NaN     ...
# 185                       NaN                     NaN     ...
# 186                       NaN                     NaN     ...
# 187                       NaN                     NaN     ...
# 188                       NaN                     NaN     ...
# 189                      -1.0                    -1.0     ...
# 190                       NaN                     NaN     ...
# 191                      40.0                    80.0     ...
# 192                       NaN                     NaN     ...
# 193                      40.0                    80.0     ...
# 194                       NaN                     NaN     ...
# 195                       NaN                     NaN     ...
# 196                     250.0                   500.0     ...
# 197                     250.0                   500.0     ...
# 198                       NaN                     NaN     ...
# 199                       NaN                     NaN     ...
# 200                       NaN                     NaN     ...
# 201                       NaN                     NaN     ...
# 202                       NaN                     NaN     ...
#
#      DATETIME_PRECISION  CHARACTER_SET_CATALOG  CHARACTER_SET_SCHEMA  \
# 0                   NaN                    NaN                   NaN
# 1                   NaN                    NaN                   NaN
# 2                   3.0                    NaN                   NaN
# 3                   NaN                    NaN                   NaN
# 4                   3.0                    NaN                   NaN
# 5                   NaN                    NaN                   NaN
# 6                   NaN                    NaN                   NaN
# 7                   NaN                    NaN                   NaN
# 8                   NaN                    NaN                   NaN
# 9                   NaN                    NaN                   NaN
# 10                  NaN                    NaN                   NaN
# 11                  NaN                    NaN                   NaN
# 12                  NaN                    NaN                   NaN
# 13                  NaN                    NaN                   NaN
# 14                  NaN                    NaN                   NaN
# 15                  NaN                    NaN                   NaN
# 16                  NaN                    NaN                   NaN
# 17                  NaN                    NaN                   NaN
# 18                  NaN                    NaN                   NaN
# 19                  NaN                    NaN                   NaN
# 20                  3.0                    NaN                   NaN
# 21                  3.0                    NaN                   NaN
# 22                  NaN                    NaN                   NaN
# 23                  NaN                    NaN                   NaN
# 24                  NaN                    NaN                   NaN
# 25                  NaN                    NaN                   NaN
# 26                  NaN                    NaN                   NaN
# 27                  NaN                    NaN                   NaN
# 28                  NaN                    NaN                   NaN
# 29                  3.0                    NaN                   NaN
# ..                  ...                    ...                   ...
# 173                 NaN                    NaN                   NaN
# 174                 NaN                    NaN                   NaN
# 175                 NaN                    NaN                   NaN
# 176                 NaN                    NaN                   NaN
# 177                 NaN                    NaN                   NaN
# 178                 NaN                    NaN                   NaN
# 179                 NaN                    NaN                   NaN
# 180                 NaN                    NaN                   NaN
# 181                 NaN                    NaN                   NaN
# 182                 NaN                    NaN                   NaN
# 183                 NaN                    NaN                   NaN
# 184                 NaN                    NaN                   NaN
# 185                 3.0                    NaN                   NaN
# 186                 3.0                    NaN                   NaN
# 187                 NaN                    NaN                   NaN
# 188                 NaN                    NaN                   NaN
# 189                 NaN                    NaN                   NaN
# 190                 NaN                    NaN                   NaN
# 191                 NaN                    NaN                   NaN
# 192                 NaN                    NaN                   NaN
# 193                 NaN                    NaN                   NaN
# 194                 3.0                    NaN                   NaN
# 195                 3.0                    NaN                   NaN
# 196                 NaN                    NaN                   NaN
# 197                 NaN                    NaN                   NaN
# 198                 NaN                    NaN                   NaN
# 199                 NaN                    NaN                   NaN
# 200                 NaN                    NaN                   NaN
# 201                 3.0                    NaN                   NaN
# 202                 3.0                    NaN                   NaN
#
#      CHARACTER_SET_NAME  COLLATION_CATALOG  COLLATION_SCHEMA  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3               UNICODE                NaN               NaN
# 4                   NaN                NaN               NaN
# 5               UNICODE                NaN               NaN
# 6               UNICODE                NaN               NaN
# 7               UNICODE                NaN               NaN
# 8                   NaN                NaN               NaN
# 9                   NaN                NaN               NaN
# 10                  NaN                NaN               NaN
# 11              UNICODE                NaN               NaN
# 12                iso_1                NaN               NaN
# 13                  NaN                NaN               NaN
# 14                  NaN                NaN               NaN
# 15              UNICODE                NaN               NaN
# 16                  NaN                NaN               NaN
# 17                  NaN                NaN               NaN
# 18                  NaN                NaN               NaN
# 19                  NaN                NaN               NaN
# 20                  NaN                NaN               NaN
# 21                  NaN                NaN               NaN
# 22                  NaN                NaN               NaN
# 23                  NaN                NaN               NaN
# 24              UNICODE                NaN               NaN
# 25                  NaN                NaN               NaN
# 26              UNICODE                NaN               NaN
# 27                  NaN                NaN               NaN
# 28              UNICODE                NaN               NaN
# 29                  NaN                NaN               NaN
# ..                  ...                ...               ...
# 173                 NaN                NaN               NaN
# 174                 NaN                NaN               NaN
# 175             UNICODE                NaN               NaN
# 176                 NaN                NaN               NaN
# 177                 NaN                NaN               NaN
# 178                 NaN                NaN               NaN
# 179                 NaN                NaN               NaN
# 180                 NaN                NaN               NaN
# 181                 NaN                NaN               NaN
# 182                 NaN                NaN               NaN
# 183                 NaN                NaN               NaN
# 184                 NaN                NaN               NaN
# 185                 NaN                NaN               NaN
# 186                 NaN                NaN               NaN
# 187                 NaN                NaN               NaN
# 188                 NaN                NaN               NaN
# 189             UNICODE                NaN               NaN
# 190                 NaN                NaN               NaN
# 191             UNICODE                NaN               NaN
# 192                 NaN                NaN               NaN
# 193             UNICODE                NaN               NaN
# 194                 NaN                NaN               NaN
# 195                 NaN                NaN               NaN
# 196             UNICODE                NaN               NaN
# 197             UNICODE                NaN               NaN
# 198                 NaN                NaN               NaN
# 199                 NaN                NaN               NaN
# 200                 NaN                NaN               NaN
# 201                 NaN                NaN               NaN
# 202                 NaN                NaN               NaN
#
#                    COLLATION_NAME  DOMAIN_CATALOG  DOMAIN_SCHEMA DOMAIN_NAME
# 0                             NaN             NaN            NaN         NaN
# 1                             NaN             NaN            NaN         NaN
# 2                             NaN             NaN            NaN         NaN
# 3    SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 4                             NaN             NaN            NaN         NaN
# 5    SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 6    SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 7    SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 8                             NaN             NaN            NaN         NaN
# 9                             NaN             NaN            NaN         NaN
# 10                            NaN             NaN            NaN         NaN
# 11   SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 12   SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 13                            NaN             NaN            NaN         NaN
# 14                            NaN             NaN            NaN         NaN
# 15   SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 16                            NaN             NaN            NaN         NaN
# 17                            NaN             NaN            NaN         NaN
# 18                            NaN             NaN            NaN         NaN
# 19                            NaN             NaN            NaN         NaN
# 20                            NaN             NaN            NaN         NaN
# 21                            NaN             NaN            NaN         NaN
# 22                            NaN             NaN            NaN         NaN
# 23                            NaN             NaN            NaN         NaN
# 24   SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 25                            NaN             NaN            NaN         NaN
# 26   SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 27                            NaN             NaN            NaN         NaN
# 28   SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 29                            NaN             NaN            NaN         NaN
# ..                            ...             ...            ...         ...
# 173                           NaN             NaN            NaN         NaN
# 174                           NaN             NaN            NaN         NaN
# 175  SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 176                           NaN             NaN            NaN         NaN
# 177                           NaN             NaN            NaN         NaN
# 178                           NaN             NaN            NaN         NaN
# 179                           NaN             NaN            NaN         NaN
# 180                           NaN             NaN            NaN         NaN
# 181                           NaN             NaN            NaN         NaN
# 182                           NaN             NaN            NaN         NaN
# 183                           NaN             NaN            NaN         NaN
# 184                           NaN             NaN            NaN         NaN
# 185                           NaN             NaN            NaN         NaN
# 186                           NaN             NaN            NaN         NaN
# 187                           NaN             NaN            NaN         NaN
# 188                           NaN             NaN            NaN         NaN
# 189  SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 190                           NaN             NaN            NaN         NaN
# 191  SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 192                           NaN             NaN            NaN         NaN
# 193  SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 194                           NaN             NaN            NaN         NaN
# 195                           NaN             NaN            NaN         NaN
# 196  SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 197  SQL_Latin1_General_CP1_CS_AS             NaN            NaN         NaN
# 198                           NaN             NaN            NaN         NaN
# 199                           NaN             NaN            NaN         NaN
# 200                           NaN             NaN            NaN         NaN
# 201                           NaN             NaN            NaN         NaN
# 202                           NaN             NaN            NaN         NaN
#
# [203 rows x 23 columns]

# %%
isc.TABLE_SCHEMA.unique()
# Out:
# array(['dbo'], dtype=object)

# %%
isc.DATA_TYPE.unique()
# Out:
# array(['int', 'datetime', 'nvarchar', 'varchar', 'tinyint',
#        'uniqueidentifier', 'bit', 'date', 'smallint'], dtype=object)

# %%
isc.CHARACTER_MAXIMUM_LENGTH.unique()
# Out:
# array([ nan,  40., 200., 100.,  -1.,  32.,  50., 250., 400., 600.,  30.,
#         35., 800., 500., 300., 150.,  80.])

# %%
# find the maximum character length specified
max_len = isc.CHARACTER_MAXIMUM_LENGTH.max()

# %%
# set the -1 values to the maximum character length specified
isc.loc[isc.CHARACTER_MAXIMUM_LENGTH == -1, 'CHARACTER_MAXIMUM_LENGTH'] = max_len
isc.loc[isc.IS_NULLABLE == 'NO', 'is_null'] = 'NOT NULL'
isc.is_null.fillna('NULL', inplace=True)
isc
# Out:
#      TABLE_CATALOG TABLE_SCHEMA        TABLE_NAME            COLUMN_NAME  \
# 0    StackOverflow          dbo             Users                     Id
# 1    StackOverflow          dbo             Users             Reputation
# 2    StackOverflow          dbo             Users           CreationDate
# 3    StackOverflow          dbo             Users            DisplayName
# 4    StackOverflow          dbo             Users         LastAccessDate
# 5    StackOverflow          dbo             Users             WebsiteUrl
# 6    StackOverflow          dbo             Users               Location
# 7    StackOverflow          dbo             Users                AboutMe
# 8    StackOverflow          dbo             Users                  Views
# 9    StackOverflow          dbo             Users                UpVotes
# 10   StackOverflow          dbo             Users              DownVotes
# 11   StackOverflow          dbo             Users        ProfileImageUrl
# 12   StackOverflow          dbo             Users              EmailHash
# 13   StackOverflow          dbo             Users              AccountId
# 14   StackOverflow          dbo         PostTypes                     Id
# 15   StackOverflow          dbo         PostTypes                   Name
# 16   StackOverflow          dbo  PostsWithDeleted                     Id
# 17   StackOverflow          dbo  PostsWithDeleted             PostTypeId
# 18   StackOverflow          dbo  PostsWithDeleted       AcceptedAnswerId
# 19   StackOverflow          dbo  PostsWithDeleted               ParentId
# 20   StackOverflow          dbo  PostsWithDeleted           CreationDate
# 21   StackOverflow          dbo  PostsWithDeleted           DeletionDate
# 22   StackOverflow          dbo  PostsWithDeleted                  Score
# 23   StackOverflow          dbo  PostsWithDeleted              ViewCount
# 24   StackOverflow          dbo  PostsWithDeleted                   Body
# 25   StackOverflow          dbo  PostsWithDeleted            OwnerUserId
# 26   StackOverflow          dbo  PostsWithDeleted       OwnerDisplayName
# 27   StackOverflow          dbo  PostsWithDeleted       LastEditorUserId
# 28   StackOverflow          dbo  PostsWithDeleted  LastEditorDisplayName
# 29   StackOverflow          dbo  PostsWithDeleted           LastEditDate
# ..             ...          ...               ...                    ...
# 173  StackOverflow          dbo       PostNotices         DeletionUserId
# 174  StackOverflow          dbo              Tags                     Id
# 175  StackOverflow          dbo              Tags                TagName
# 176  StackOverflow          dbo              Tags                  Count
# 177  StackOverflow          dbo              Tags          ExcerptPostId
# 178  StackOverflow          dbo              Tags             WikiPostId
# 179  StackOverflow          dbo          PostTags                 PostId
# 180  StackOverflow          dbo          PostTags                  TagId
# 181  StackOverflow          dbo             Posts                     Id
# 182  StackOverflow          dbo             Posts             PostTypeId
# 183  StackOverflow          dbo             Posts       AcceptedAnswerId
# 184  StackOverflow          dbo             Posts               ParentId
# 185  StackOverflow          dbo             Posts           CreationDate
# 186  StackOverflow          dbo             Posts           DeletionDate
# 187  StackOverflow          dbo             Posts                  Score
# 188  StackOverflow          dbo             Posts              ViewCount
# 189  StackOverflow          dbo             Posts                   Body
# 190  StackOverflow          dbo             Posts            OwnerUserId
# 191  StackOverflow          dbo             Posts       OwnerDisplayName
# 192  StackOverflow          dbo             Posts       LastEditorUserId
# 193  StackOverflow          dbo             Posts  LastEditorDisplayName
# 194  StackOverflow          dbo             Posts           LastEditDate
# 195  StackOverflow          dbo             Posts       LastActivityDate
# 196  StackOverflow          dbo             Posts                  Title
# 197  StackOverflow          dbo             Posts                   Tags
# 198  StackOverflow          dbo             Posts            AnswerCount
# 199  StackOverflow          dbo             Posts           CommentCount
# 200  StackOverflow          dbo             Posts          FavoriteCount
# 201  StackOverflow          dbo             Posts             ClosedDate
# 202  StackOverflow          dbo             Posts     CommunityOwnedDate
#
#      ORDINAL_POSITION  COLUMN_DEFAULT IS_NULLABLE DATA_TYPE  \
# 0                   1             NaN          NO       int
# 1                   2             NaN          NO       int
# 2                   3             NaN          NO  datetime
# 3                   4             NaN         YES  nvarchar
# 4                   5             NaN          NO  datetime
# 5                   6             NaN         YES  nvarchar
# 6                   7             NaN         YES  nvarchar
# 7                   8             NaN         YES  nvarchar
# 8                   9             NaN          NO       int
# 9                  10             NaN          NO       int
# 10                 11             NaN          NO       int
# 11                 12             NaN         YES  nvarchar
# 12                 13             NaN         YES   varchar
# 13                 14             NaN         YES       int
# 14                  1             NaN          NO   tinyint
# 15                  2             NaN          NO  nvarchar
# 16                  1             NaN          NO       int
# 17                  2             NaN          NO   tinyint
# 18                  3             NaN         YES       int
# 19                  4             NaN         YES       int
# 20                  5             NaN          NO  datetime
# 21                  6             NaN         YES  datetime
# 22                  7             NaN          NO       int
# 23                  8             NaN         YES       int
# 24                  9             NaN         YES  nvarchar
# 25                 10             NaN         YES       int
# 26                 11             NaN         YES  nvarchar
# 27                 12             NaN         YES       int
# 28                 13             NaN         YES  nvarchar
# 29                 14             NaN         YES  datetime
# ..                ...             ...         ...       ...
# 173                 9             NaN         YES       int
# 174                 1             NaN          NO       int
# 175                 2             NaN         YES  nvarchar
# 176                 3             NaN          NO       int
# 177                 4             NaN         YES       int
# 178                 5             NaN         YES       int
# 179                 1             NaN          NO       int
# 180                 2             NaN          NO       int
# 181                 1             NaN          NO       int
# 182                 2             NaN          NO   tinyint
# 183                 3             NaN         YES       int
# 184                 4             NaN         YES       int
# 185                 5             NaN          NO  datetime
# 186                 6             NaN         YES  datetime
# 187                 7             NaN          NO       int
# 188                 8             NaN         YES       int
# 189                 9             NaN         YES  nvarchar
# 190                10             NaN         YES       int
# 191                11             NaN         YES  nvarchar
# 192                12             NaN         YES       int
# 193                13             NaN         YES  nvarchar
# 194                14             NaN         YES  datetime
# 195                15             NaN         YES  datetime
# 196                16             NaN         YES  nvarchar
# 197                17             NaN         YES  nvarchar
# 198                18             NaN         YES       int
# 199                19             NaN         YES       int
# 200                20             NaN         YES       int
# 201                21             NaN         YES  datetime
# 202                22             NaN         YES  datetime
#
#      CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH       ...         \
# 0                         NaN                     NaN       ...
# 1                         NaN                     NaN       ...
# 2                         NaN                     NaN       ...
# 3                        40.0                    80.0       ...
# 4                         NaN                     NaN       ...
# 5                       200.0                   400.0       ...
# 6                       100.0                   200.0       ...
# 7                       800.0                    -1.0       ...
# 8                         NaN                     NaN       ...
# 9                         NaN                     NaN       ...
# 10                        NaN                     NaN       ...
# 11                      200.0                   400.0       ...
# 12                       32.0                    32.0       ...
# 13                        NaN                     NaN       ...
# 14                        NaN                     NaN       ...
# 15                       50.0                   100.0       ...
# 16                        NaN                     NaN       ...
# 17                        NaN                     NaN       ...
# 18                        NaN                     NaN       ...
# 19                        NaN                     NaN       ...
# 20                        NaN                     NaN       ...
# 21                        NaN                     NaN       ...
# 22                        NaN                     NaN       ...
# 23                        NaN                     NaN       ...
# 24                      800.0                    -1.0       ...
# 25                        NaN                     NaN       ...
# 26                       40.0                    80.0       ...
# 27                        NaN                     NaN       ...
# 28                       40.0                    80.0       ...
# 29                        NaN                     NaN       ...
# ..                        ...                     ...       ...
# 173                       NaN                     NaN       ...
# 174                       NaN                     NaN       ...
# 175                      35.0                    70.0       ...
# 176                       NaN                     NaN       ...
# 177                       NaN                     NaN       ...
# 178                       NaN                     NaN       ...
# 179                       NaN                     NaN       ...
# 180                       NaN                     NaN       ...
# 181                       NaN                     NaN       ...
# 182                       NaN                     NaN       ...
# 183                       NaN                     NaN       ...
# 184                       NaN                     NaN       ...
# 185                       NaN                     NaN       ...
# 186                       NaN                     NaN       ...
# 187                       NaN                     NaN       ...
# 188                       NaN                     NaN       ...
# 189                     800.0                    -1.0       ...
# 190                       NaN                     NaN       ...
# 191                      40.0                    80.0       ...
# 192                       NaN                     NaN       ...
# 193                      40.0                    80.0       ...
# 194                       NaN                     NaN       ...
# 195                       NaN                     NaN       ...
# 196                     250.0                   500.0       ...
# 197                     250.0                   500.0       ...
# 198                       NaN                     NaN       ...
# 199                       NaN                     NaN       ...
# 200                       NaN                     NaN       ...
# 201                       NaN                     NaN       ...
# 202                       NaN                     NaN       ...
#
#      CHARACTER_SET_SCHEMA  CHARACTER_SET_NAME  COLLATION_CATALOG  \
# 0                     NaN                 NaN                NaN
# 1                     NaN                 NaN                NaN
# 2                     NaN                 NaN                NaN
# 3                     NaN             UNICODE                NaN
# 4                     NaN                 NaN                NaN
# 5                     NaN             UNICODE                NaN
# 6                     NaN             UNICODE                NaN
# 7                     NaN             UNICODE                NaN
# 8                     NaN                 NaN                NaN
# 9                     NaN                 NaN                NaN
# 10                    NaN                 NaN                NaN
# 11                    NaN             UNICODE                NaN
# 12                    NaN               iso_1                NaN
# 13                    NaN                 NaN                NaN
# 14                    NaN                 NaN                NaN
# 15                    NaN             UNICODE                NaN
# 16                    NaN                 NaN                NaN
# 17                    NaN                 NaN                NaN
# 18                    NaN                 NaN                NaN
# 19                    NaN                 NaN                NaN
# 20                    NaN                 NaN                NaN
# 21                    NaN                 NaN                NaN
# 22                    NaN                 NaN                NaN
# 23                    NaN                 NaN                NaN
# 24                    NaN             UNICODE                NaN
# 25                    NaN                 NaN                NaN
# 26                    NaN             UNICODE                NaN
# 27                    NaN                 NaN                NaN
# 28                    NaN             UNICODE                NaN
# 29                    NaN                 NaN                NaN
# ..                    ...                 ...                ...
# 173                   NaN                 NaN                NaN
# 174                   NaN                 NaN                NaN
# 175                   NaN             UNICODE                NaN
# 176                   NaN                 NaN                NaN
# 177                   NaN                 NaN                NaN
# 178                   NaN                 NaN                NaN
# 179                   NaN                 NaN                NaN
# 180                   NaN                 NaN                NaN
# 181                   NaN                 NaN                NaN
# 182                   NaN                 NaN                NaN
# 183                   NaN                 NaN                NaN
# 184                   NaN                 NaN                NaN
# 185                   NaN                 NaN                NaN
# 186                   NaN                 NaN                NaN
# 187                   NaN                 NaN                NaN
# 188                   NaN                 NaN                NaN
# 189                   NaN             UNICODE                NaN
# 190                   NaN                 NaN                NaN
# 191                   NaN             UNICODE                NaN
# 192                   NaN                 NaN                NaN
# 193                   NaN             UNICODE                NaN
# 194                   NaN                 NaN                NaN
# 195                   NaN                 NaN                NaN
# 196                   NaN             UNICODE                NaN
# 197                   NaN             UNICODE                NaN
# 198                   NaN                 NaN                NaN
# 199                   NaN                 NaN                NaN
# 200                   NaN                 NaN                NaN
# 201                   NaN                 NaN                NaN
# 202                   NaN                 NaN                NaN
#
#      COLLATION_SCHEMA                COLLATION_NAME  DOMAIN_CATALOG  \
# 0                 NaN                           NaN             NaN
# 1                 NaN                           NaN             NaN
# 2                 NaN                           NaN             NaN
# 3                 NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 4                 NaN                           NaN             NaN
# 5                 NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 6                 NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 7                 NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 8                 NaN                           NaN             NaN
# 9                 NaN                           NaN             NaN
# 10                NaN                           NaN             NaN
# 11                NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 12                NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 13                NaN                           NaN             NaN
# 14                NaN                           NaN             NaN
# 15                NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 16                NaN                           NaN             NaN
# 17                NaN                           NaN             NaN
# 18                NaN                           NaN             NaN
# 19                NaN                           NaN             NaN
# 20                NaN                           NaN             NaN
# 21                NaN                           NaN             NaN
# 22                NaN                           NaN             NaN
# 23                NaN                           NaN             NaN
# 24                NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 25                NaN                           NaN             NaN
# 26                NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 27                NaN                           NaN             NaN
# 28                NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 29                NaN                           NaN             NaN
# ..                ...                           ...             ...
# 173               NaN                           NaN             NaN
# 174               NaN                           NaN             NaN
# 175               NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 176               NaN                           NaN             NaN
# 177               NaN                           NaN             NaN
# 178               NaN                           NaN             NaN
# 179               NaN                           NaN             NaN
# 180               NaN                           NaN             NaN
# 181               NaN                           NaN             NaN
# 182               NaN                           NaN             NaN
# 183               NaN                           NaN             NaN
# 184               NaN                           NaN             NaN
# 185               NaN                           NaN             NaN
# 186               NaN                           NaN             NaN
# 187               NaN                           NaN             NaN
# 188               NaN                           NaN             NaN
# 189               NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 190               NaN                           NaN             NaN
# 191               NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 192               NaN                           NaN             NaN
# 193               NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 194               NaN                           NaN             NaN
# 195               NaN                           NaN             NaN
# 196               NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 197               NaN  SQL_Latin1_General_CP1_CS_AS             NaN
# 198               NaN                           NaN             NaN
# 199               NaN                           NaN             NaN
# 200               NaN                           NaN             NaN
# 201               NaN                           NaN             NaN
# 202               NaN                           NaN             NaN
#
#     DOMAIN_SCHEMA  DOMAIN_NAME   is_null datatype_lenprec
# 0             NaN          NaN  NOT NULL          int(10)
# 1             NaN          NaN  NOT NULL          int(10)
# 2             NaN          NaN  NOT NULL         datetime
# 3             NaN          NaN      NULL     nvarchar(40)
# 4             NaN          NaN  NOT NULL         datetime
# 5             NaN          NaN      NULL    nvarchar(200)
# 6             NaN          NaN      NULL    nvarchar(100)
# 7             NaN          NaN      NULL    nvarchar(800)
# 8             NaN          NaN  NOT NULL          int(10)
# 9             NaN          NaN  NOT NULL          int(10)
# 10            NaN          NaN  NOT NULL          int(10)
# 11            NaN          NaN      NULL    nvarchar(200)
# 12            NaN          NaN      NULL      varchar(32)
# 13            NaN          NaN      NULL          int(10)
# 14            NaN          NaN  NOT NULL       tinyint(3)
# 15            NaN          NaN  NOT NULL     nvarchar(50)
# 16            NaN          NaN  NOT NULL          int(10)
# 17            NaN          NaN  NOT NULL       tinyint(3)
# 18            NaN          NaN      NULL          int(10)
# 19            NaN          NaN      NULL          int(10)
# 20            NaN          NaN  NOT NULL         datetime
# 21            NaN          NaN      NULL         datetime
# 22            NaN          NaN  NOT NULL          int(10)
# 23            NaN          NaN      NULL          int(10)
# 24            NaN          NaN      NULL    nvarchar(800)
# 25            NaN          NaN      NULL          int(10)
# 26            NaN          NaN      NULL     nvarchar(40)
# 27            NaN          NaN      NULL          int(10)
# 28            NaN          NaN      NULL     nvarchar(40)
# 29            NaN          NaN      NULL         datetime
# ..            ...          ...       ...              ...
# 173           NaN          NaN      NULL          int(10)
# 174           NaN          NaN  NOT NULL          int(10)
# 175           NaN          NaN      NULL     nvarchar(35)
# 176           NaN          NaN  NOT NULL          int(10)
# 177           NaN          NaN      NULL          int(10)
# 178           NaN          NaN      NULL          int(10)
# 179           NaN          NaN  NOT NULL          int(10)
# 180           NaN          NaN  NOT NULL          int(10)
# 181           NaN          NaN  NOT NULL          int(10)
# 182           NaN          NaN  NOT NULL       tinyint(3)
# 183           NaN          NaN      NULL          int(10)
# 184           NaN          NaN      NULL          int(10)
# 185           NaN          NaN  NOT NULL         datetime
# 186           NaN          NaN      NULL         datetime
# 187           NaN          NaN  NOT NULL          int(10)
# 188           NaN          NaN      NULL          int(10)
# 189           NaN          NaN      NULL    nvarchar(800)
# 190           NaN          NaN      NULL          int(10)
# 191           NaN          NaN      NULL     nvarchar(40)
# 192           NaN          NaN      NULL          int(10)
# 193           NaN          NaN      NULL     nvarchar(40)
# 194           NaN          NaN      NULL         datetime
# 195           NaN          NaN      NULL         datetime
# 196           NaN          NaN      NULL    nvarchar(250)
# 197           NaN          NaN      NULL    nvarchar(250)
# 198           NaN          NaN      NULL          int(10)
# 199           NaN          NaN      NULL          int(10)
# 200           NaN          NaN      NULL          int(10)
# 201           NaN          NaN      NULL         datetime
# 202           NaN          NaN      NULL         datetime
#
# [203 rows x 25 columns]

# %%
def len_prec(row):
    if 'varchar' in row.DATA_TYPE: 
        val = row.DATA_TYPE + "(" + str(int(row.CHARACTER_MAXIMUM_LENGTH)) + ")"
    elif 'int' in row.DATA_TYPE:
        val = row.DATA_TYPE + "(" + str(int(row.NUMERIC_PRECISION)) + ")"
    else:
        val = row.DATA_TYPE
    return val

isc['datatype_lenprec'] = isc.transform(len_prec, axis=1)
isct = isc.loc[isc.TABLE_NAME == 'Users', ['TABLE_NAME', 'ORDINAL_POSITION', 'COLUMN_NAME',
       'DATA_TYPE', 'CHARACTER_MAXIMUM_LENGTH', 'datatype_lenprec']]
isct
# Out:
#    TABLE_NAME  ORDINAL_POSITION      COLUMN_NAME DATA_TYPE  \
# 0       Users                 1               Id       int
# 1       Users                 2       Reputation       int
# 2       Users                 3     CreationDate  datetime
# 3       Users                 4      DisplayName  nvarchar
# 4       Users                 5   LastAccessDate  datetime
# 5       Users                 6       WebsiteUrl  nvarchar
# 6       Users                 7         Location  nvarchar
# 7       Users                 8          AboutMe  nvarchar
# 8       Users                 9            Views       int
# 9       Users                10          UpVotes       int
# 10      Users                11        DownVotes       int
# 11      Users                12  ProfileImageUrl  nvarchar
# 12      Users                13        EmailHash   varchar
# 13      Users                14        AccountId       int
#
#     CHARACTER_MAXIMUM_LENGTH datatype_lenprec
# 0                        NaN          int(10)
# 1                        NaN          int(10)
# 2                        NaN         datetime
# 3                       40.0     nvarchar(40)
# 4                        NaN         datetime
# 5                      200.0    nvarchar(200)
# 6                      100.0    nvarchar(100)
# 7                      800.0    nvarchar(800)
# 8                        NaN          int(10)
# 9                        NaN          int(10)
# 10                       NaN          int(10)
# 11                     200.0    nvarchar(200)
# 12                      32.0      varchar(32)
# 13                       NaN          int(10)

# %%
# list of all the tables
ist = isc.groupby('TABLE_NAME').min().reset_index()['TABLE_NAME'].to_frame()
ist
# Out:
#                     TABLE_NAME
# 0                       Badges
# 1   CloseAsOffTopicReasonTypes
# 2             CloseReasonTypes
# 3                     Comments
# 4                    FlagTypes
# 5                 PendingFlags
# 6                 PostFeedback
# 7                  PostHistory
# 8             PostHistoryTypes
# 9                    PostLinks
# 10             PostNoticeTypes
# 11                 PostNotices
# 12                    PostTags
# 13                   PostTypes
# 14                       Posts
# 15            PostsWithDeleted
# 16      ReviewRejectionReasons
# 17       ReviewTaskResultTypes
# 18           ReviewTaskResults
# 19            ReviewTaskStates
# 20             ReviewTaskTypes
# 21                 ReviewTasks
# 22          SuggestedEditVotes
# 23              SuggestedEdits
# 24                 TagSynonyms
# 25                        Tags
# 26                       Users
# 27                   VoteTypes
# 28                       Votes

# %%
def create_attrib(grp):
    return "\t".join(grp.COLUMN_NAME + " " + grp.datatype_lenprec + " " + grp.is_null + ",\n")

new_attribs = (isc
               .groupby('TABLE_NAME')
               .apply(create_attrib)
               .to_frame(name='attribs')
              )

# %%
new_df = pd.merge(ist, new_attribs, on='TABLE_NAME')

# %%
def create_table(tbl_grp):
    return "\nCREATE TABLE " + tbl_grp.TABLE_NAME + " (\n\t" + \
                tbl_grp.attribs + \
            "\tPRIMARY KEY ( Id )\n); \
            \n"
df_script = (new_df
             .groupby('TABLE_NAME')
             .apply(create_table)
             .to_frame(name='create_table_script')
             .reset_index().create_table_script
            )
df_script
# Out:
# 0     \nCREATE TABLE Badges (\n\tId int(10) NOT NULL...
# 1     \nCREATE TABLE CloseAsOffTopicReasonTypes (\n\...
# 2     \nCREATE TABLE CloseReasonTypes (\n\tId tinyin...
# 3     \nCREATE TABLE Comments (\n\tId int(10) NOT NU...
# 4     \nCREATE TABLE FlagTypes (\n\tId tinyint(3) NO...
# 5     \nCREATE TABLE PendingFlags (\n\tId int(10) NO...
# 6     \nCREATE TABLE PostFeedback (\n\tId int(10) NO...
# 7     \nCREATE TABLE PostHistory (\n\tId int(10) NOT...
# 8     \nCREATE TABLE PostHistoryTypes (\n\tId tinyin...
# 9     \nCREATE TABLE PostLinks (\n\tId int(10) NOT N...
# 10    \nCREATE TABLE PostNoticeTypes (\n\tId int(10)...
# 11    \nCREATE TABLE PostNotices (\n\tId int(10) NOT...
# 12    \nCREATE TABLE PostTags (\n\tPostId int(10) NO...
# 13    \nCREATE TABLE PostTypes (\n\tId tinyint(3) NO...
# 14    \nCREATE TABLE Posts (\n\tId int(10) NOT NULL,...
# 15    \nCREATE TABLE PostsWithDeleted (\n\tId int(10...
# 16    \nCREATE TABLE ReviewRejectionReasons (\n\tId ...
# 17    \nCREATE TABLE ReviewTaskResultTypes (\n\tId t...
# 18    \nCREATE TABLE ReviewTaskResults (\n\tId int(1...
# 19    \nCREATE TABLE ReviewTaskStates (\n\tId tinyin...
# 20    \nCREATE TABLE ReviewTaskTypes (\n\tId tinyint...
# 21    \nCREATE TABLE ReviewTasks (\n\tId int(10) NOT...
# 22    \nCREATE TABLE SuggestedEditVotes (\n\tId int(...
# 23    \nCREATE TABLE SuggestedEdits (\n\tId int(10) ...
# 24    \nCREATE TABLE TagSynonyms (\n\tId int(10) NOT...
# 25    \nCREATE TABLE Tags (\n\tId int(10) NOT NULL,\...
# 26    \nCREATE TABLE Users (\n\tId int(10) NOT NULL,...
# 27    \nCREATE TABLE VoteTypes (\n\tId tinyint(3) NO...
# 28    \nCREATE TABLE Votes (\n\tId int(10) NOT NULL,...
# Name: create_table_script, dtype: object

# %%
# write script into a csv
## it will write each table as an individual string
df_script.to_csv("new_script.csv", index = False)

# %%
# Select all columns with ID in the name
isid = isc.loc[isc.COLUMN_NAME.str.contains('Id'), ['TABLE_NAME', 'COLUMN_NAME']]
# drop all the primary key column names
isid = isid.loc[isid.COLUMN_NAME != 'Id', :]
# extrapolate the foreign table's name from the Id Columns Prefixed name
isid['id_prefix'] = isid.COLUMN_NAME.str.extract(r'(?P<foreign>^.*)Id')
isid['projected_foreign_table'] = isid.id_prefix + 's'
# create column containing boolean of check to see if projected table is in list of tables
isid.loc[isid.projected_foreign_table.isin(list(ist.TABLE_NAME)), 'is_table'] = True

# display the collection that correspond correctly to the tables
istid = isid.loc[isid.is_table == True, :]
istid
# isid.loc[isid.is_table != True]
# isid
# Out:
#                  TABLE_NAME                  COLUMN_NAME  \
# 17         PostsWithDeleted                   PostTypeId
# 41              PostHistory            PostHistoryTypeId
# 42              PostHistory                       PostId
# 45              PostHistory                       UserId
# 52                    Votes                       PostId
# 53                    Votes                   VoteTypeId
# 54                    Votes                       UserId
# 58                   Badges                       UserId
# 64                 Comments                       PostId
# 69                 Comments                       UserId
# 81             PostFeedback                       PostId
# 83             PostFeedback                   VoteTypeId
# 86           SuggestedEdits                       PostId
# 97       SuggestedEditVotes              SuggestedEditId
# 98       SuggestedEditVotes                       UserId
# 99       SuggestedEditVotes                   VoteTypeId
# 105               PostLinks                       PostId
# 112            PendingFlags                   FlagTypeId
# 113            PendingFlags                       PostId
# 115            PendingFlags            CloseReasonTypeId
# 116            PendingFlags  CloseAsOffTopicReasonTypeId
# 132             ReviewTasks             ReviewTaskTypeId
# 135             ReviewTasks            ReviewTaskStateId
# 136             ReviewTasks                       PostId
# 137             ReviewTasks              SuggestedEditId
# 146       ReviewTaskResults                 ReviewTaskId
# 147       ReviewTaskResults       ReviewTaskResultTypeId
# 157  ReviewRejectionReasons                   PostTypeId
# 166             PostNotices                       PostId
# 167             PostNotices             PostNoticeTypeId
# 179                PostTags                       PostId
# 180                PostTags                        TagId
# 182                   Posts                   PostTypeId
#
#                      id_prefix     projected_foreign_table is_table
# 17                    PostType                   PostTypes     True
# 41             PostHistoryType            PostHistoryTypes     True
# 42                        Post                       Posts     True
# 45                        User                       Users     True
# 52                        Post                       Posts     True
# 53                    VoteType                   VoteTypes     True
# 54                        User                       Users     True
# 58                        User                       Users     True
# 64                        Post                       Posts     True
# 69                        User                       Users     True
# 81                        Post                       Posts     True
# 83                    VoteType                   VoteTypes     True
# 86                        Post                       Posts     True
# 97               SuggestedEdit              SuggestedEdits     True
# 98                        User                       Users     True
# 99                    VoteType                   VoteTypes     True
# 105                       Post                       Posts     True
# 112                   FlagType                   FlagTypes     True
# 113                       Post                       Posts     True
# 115            CloseReasonType            CloseReasonTypes     True
# 116  CloseAsOffTopicReasonType  CloseAsOffTopicReasonTypes     True
# 132             ReviewTaskType             ReviewTaskTypes     True
# 135            ReviewTaskState            ReviewTaskStates     True
# 136                       Post                       Posts     True
# 137              SuggestedEdit              SuggestedEdits     True
# 146                 ReviewTask                 ReviewTasks     True
# 147       ReviewTaskResultType       ReviewTaskResultTypes     True
# 157                   PostType                   PostTypes     True
# 166                       Post                       Posts     True
# 167             PostNoticeType             PostNoticeTypes     True
# 179                       Post                       Posts     True
# 180                        Tag                        Tags     True
# 182                   PostType                   PostTypes     True

# %%
# sample foreign key constraint format
# ALTER TABLE PostTags 
# ADD CONSTRAINT Fk_PostTags_Posts FOREIGN KEY ( PostId ) 
# REFERENCES Posts( Id ) ;

# create function to script out constraints from table rows
def create_fk_constraints(row):
    return "\n\
ALTER TABLE {tbl_name} \n\
ADD CONSTRAINT Fk_{tbl_name}_{frgn_tbl} FOREIGN KEY ( {col_name} ) \n\
REFERENCES {frgn_tbl}( Id ) ;\n" \
    .format(tbl_name = row.TABLE_NAME,\
            col_name = row.COLUMN_NAME,\
            frgn_tbl = row.projected_foreign_table
           )
            
# # singleton test
# create_fk_constraints(isid.iloc[0,:])

# create_fk_script for the standard pk_Table.ID_fk_TableId pairs 
create_fk_script = (istid
                    .apply(create_fk_constraints, axis = 1)
                   )

# append the fk constraints to the table create script
with open('new_script.csv', 'a') as create_table_script:
    (create_fk_script
     .to_csv(create_table_script, header = False, index = False)
    )

# %%
# create pk_fk constraints for the secondary fk's
## select out just the non-standard fk_id's referencing the user tables
isuid = (isid
         .loc[isid.is_table != True, 'TABLE_NAME':'id_prefix']
         .loc[isid.COLUMN_NAME.str.contains('User|Moderator'), :]    
        )
## add in the correct projected table for this Users subsets
isuid['projected_foreign_table'] = 'Users'

# create a script for the non-standard users foreign keys
create_users_fk_script = isuid.apply(create_fk_constraints, axis = 1)

# append the non-standard user_id fk constraints to the creation and standard FK_scripts
with open('new_script.csv', 'a') as create_table_script:
    create_users_fk_script.to_csv(create_table_script, header = False, index = False)

isuid
# Out:
#                      TABLE_NAME              COLUMN_NAME  \
# 25             PostsWithDeleted              OwnerUserId
# 27             PostsWithDeleted         LastEditorUserId
# 74                  TagSynonyms              OwnerUserId
# 78                  TagSynonyms         ApprovedByUserId
# 90               SuggestedEdits              OwnerUserId
# 101          SuggestedEditVotes             TargetUserId
# 126  CloseAsOffTopicReasonTypes      CreationModeratorId
# 128  CloseAsOffTopicReasonTypes      ApprovalModeratorId
# 130  CloseAsOffTopicReasonTypes  DeactivationModeratorId
# 172                 PostNotices              OwnerUserId
# 173                 PostNotices           DeletionUserId
# 190                       Posts              OwnerUserId
# 192                       Posts         LastEditorUserId
#
#                  id_prefix projected_foreign_table
# 25               OwnerUser                   Users
# 27          LastEditorUser                   Users
# 74               OwnerUser                   Users
# 78          ApprovedByUser                   Users
# 90               OwnerUser                   Users
# 101             TargetUser                   Users
# 126      CreationModerator                   Users
# 128      ApprovalModerator                   Users
# 130  DeactivationModerator                   Users
# 172              OwnerUser                   Users
# 173           DeletionUser                   Users
# 190              OwnerUser                   Users
# 192         LastEditorUser                   Users

# %%
# select what hasn't been handled yet
isnuid = isid.loc[(isid.is_table != True) & (isid.COLUMN_NAME.str.contains('User|Moderator') == False), :]
isnuid
# Out:
#             TABLE_NAME              COLUMN_NAME              id_prefix  \
# 13               Users                AccountId                Account
# 18    PostsWithDeleted         AcceptedAnswerId         AcceptedAnswer
# 19    PostsWithDeleted                 ParentId                 Parent
# 106          PostLinks            RelatedPostId            RelatedPost
# 107          PostLinks               LinkTypeId               LinkType
# 117       PendingFlags    DuplicateOfQuestionId    DuplicateOfQuestion
# 138        ReviewTasks  CompletedByReviewTaskId  CompletedByReviewTask
# 149  ReviewTaskResults        RejectionReasonId        RejectionReason
# 159    PostNoticeTypes                  ClassId                  Class
# 164    PostNoticeTypes     PostNoticeDurationId     PostNoticeDuration
# 177               Tags            ExcerptPostId            ExcerptPost
# 178               Tags               WikiPostId               WikiPost
# 183              Posts         AcceptedAnswerId         AcceptedAnswer
# 184              Posts                 ParentId                 Parent
#
#     projected_foreign_table is_table
# 13                 Accounts      NaN
# 18          AcceptedAnswers      NaN
# 19                  Parents      NaN
# 106            RelatedPosts      NaN
# 107               LinkTypes      NaN
# 117    DuplicateOfQuestions      NaN
# 138  CompletedByReviewTasks      NaN
# 149        RejectionReasons      NaN
# 159                  Classs      NaN
# 164     PostNoticeDurations      NaN
# 177            ExcerptPosts      NaN
# 178               WikiPosts      NaN
# 183         AcceptedAnswers      NaN
# 184                 Parents      NaN

# %%
# anything with Posts in TableName needs to reference Posts Id
## except link type Id (1 = relatedPost, 3 = duplicate)
## except PostNoticeTypes Table_name

ispid = (isnuid
         .loc[(isnuid.TABLE_NAME.str.contains('Post')) | \
              (isnuid.COLUMN_NAME.str.contains('Post|DuplicateOfQuestionId')), :
             ]
         .loc[(isnuid.TABLE_NAME.str.contains('Type') == False) & \
              (isnuid.COLUMN_NAME.str.contains('Type') == False), :
             ]
        )
## add in the correct projected table for this Posts subset
ispid['projected_foreign_table'] = 'Posts'

# create a script for the non-standard users foreign keys
create_posts_fk_script = ispid.apply(create_fk_constraints, axis = 1)

# append the non-standard post_id fk constraints to the creation and standard FK_scripts
with open('new_script.csv', 'a') as create_table_script:
    create_posts_fk_script.to_csv(create_table_script, header = False, index = False)
ispid
# Out:
#            TABLE_NAME            COLUMN_NAME            id_prefix  \
# 18   PostsWithDeleted       AcceptedAnswerId       AcceptedAnswer
# 19   PostsWithDeleted               ParentId               Parent
# 106         PostLinks          RelatedPostId          RelatedPost
# 117      PendingFlags  DuplicateOfQuestionId  DuplicateOfQuestion
# 177              Tags          ExcerptPostId          ExcerptPost
# 178              Tags             WikiPostId             WikiPost
# 183             Posts       AcceptedAnswerId       AcceptedAnswer
# 184             Posts               ParentId               Parent
#
#     projected_foreign_table is_table
# 18                    Posts      NaN
# 19                    Posts      NaN
# 106                   Posts      NaN
# 117                   Posts      NaN
# 177                   Posts      NaN
# 178                   Posts      NaN
# 183                   Posts      NaN
# 184                   Posts      NaN

# %%
# gather together all the columns that were 
from itertools import chain
constraints_already_added = list(chain(istid.index.values, isuid.index.values, ispid.index.values))
# isid.loc[isid.isin(constraints_already_added), :]
isid[~isid.index.isin(constraints_already_added)]
# Out:
#             TABLE_NAME              COLUMN_NAME              id_prefix  \
# 13               Users                AccountId                Account
# 107          PostLinks               LinkTypeId               LinkType
# 138        ReviewTasks  CompletedByReviewTaskId  CompletedByReviewTask
# 149  ReviewTaskResults        RejectionReasonId        RejectionReason
# 159    PostNoticeTypes                  ClassId                  Class
# 164    PostNoticeTypes     PostNoticeDurationId     PostNoticeDuration
#
#     projected_foreign_table is_table
# 13                 Accounts      NaN
# 107               LinkTypes      NaN
# 138  CompletedByReviewTasks      NaN
# 149        RejectionReasons      NaN
# 159                  Classs      NaN
# 164     PostNoticeDurations      NaN

# %%
# handling the naming convention outliers

## ReviewTaskResults.RejectionReasonId to reference ReviewRejectionReasons.Id
create_reviewtaskresults_fk = "\n\
ALTER TABLE ReviewTaskResults \n\
ADD CONSTRAINT Fk_ReviewTaskResults_ReviewRejectionReasons FOREIGN KEY ( RejectionReasonId ) \n\
REFERENCES ReviewRejectionReasons( Id ) ;\n"

## ReviewTasks.CompletedByReviewTaskId to reference ReviewTaskResults.Id
create_reviewtasks_fk = "\n\
ALTER TABLE ReviewTasks \n\
ADD CONSTRAINT Fk_ReviewTasks_CompletedByReviewTaskId FOREIGN KEY ( CompletedByReviewTaskId ) \n\
REFERENCES ReviewTaskResults( Id ) ;\n"

## TagSynonyms.SourceTagName to reference Tags.TagName
## TagSynonyms.TargetTagName to reference Tags.TagName
create_tagsynonyms_tagnames_fk = "\n\
ALTER TABLE TagSynonyms \n\
ADD CONSTRAINT Fk_TagSynonymsSourceTagName_Tags FOREIGN KEY ( SourceTagName ) \n\
REFERENCES Tags( TagName ) ;\n\
ALTER TABLE TagSynonyms \n\
ADD CONSTRAINT Fk_TagSynonymsTargetTagName_Tags FOREIGN KEY ( TargetTagName ) \n\
REFERENCES Tags( TagName ) ;\n"


# combine outlier strings into single series
create_singleton_fks = pd.Series([create_reviewtaskresults_fk,\
                                  create_reviewtasks_fk,\
                                  create_tagsynonyms_tagnames_fk])

# append the singletons into the script
with open('new_script.csv', 'a') as create_table_script:
    create_singleton_fks.to_csv(create_table_script, index = False)

# %%
# rewrite the script with all of the string quotes and extra line endings removed.
def organize_data(location='./new_script.csv'):
    with open(location, "r", encoding="utf-8") as f:
        name_string = f.read()
        name_string = name_string.replace('"\n"','')
        name_string = name_string.replace('"', '')
    return name_string



text_file = open("info_schema_create_tables.sql", "w")
text_file.write(organize_data())
text_file.close()
# organize_data().write('quote_free_script.csv')
